# %% [markdown]
# # LINEAR LEARNER

# %%
import pandas as pd
import numpy as np
import sagemaker
import os
from utils import standardize_data
from sagemaker import LinearLearner
from sagemaker import get_execution_role
import gc

# specify an output path
prefix = 'wildfire'
data_dir = 'wildfire_data'
sagemaker_session = sagemaker.Session()
bucket = sagemaker_session.default_bucket()
output_path = 's3://{}/{}'.format(bucket, prefix)
role = get_execution_role()

# %%
multiclass_estimator = LinearLearner(role=role,
                       train_instance_count=1, 
                       train_instance_type='ml.c4.xlarge',
                       predictor_type='multiclass_classifier',
                       num_classes=13,
                       balance_multiclass_weights=True,
                       output_path=output_path,
                       sagemaker_session=sagemaker_session,
                       epochs=50)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
gc.collect()
train = pd.read_csv(os.path.join(data_dir, 'train.csv'), header=None, dtype="float32")
val = pd.read_csv(os.path.join(data_dir, 'validation.csv'), header=None, dtype="float32")
test_x = pd.read_csv(os.path.join(data_dir, 'test.csv'), header=None, dtype="float32")
test_y = pd.read_csv(os.path.join(data_dir, 'test_y.csv'), header=None, dtype="float32")

# %%
train_y_np = train.iloc[:,0].values
train.drop([0], axis = 1, inplace = True)
train_x_np = train.values
train=None
gc.collect()
val_y_np = val.iloc[:,0].values
val.drop([0], axis = 1, inplace = True)
val_x_np = val.values
del val

# %%
formatted_train_data = multiclass_estimator.record_set(train_x_np, labels=train_y_np, channel='train')
formatted_val_data = multiclass_estimator.record_set(val_x_np, labels=val_y_np, channel='validation')

# %%
multiclass_estimator.fit([formatted_train_data, formatted_val_data])
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-02-07 06:54:15 Starting - Starting the training job...
# 2021-02-07 06:54:20 Starting - Launching requested ML instancesProfilerReport-1612680855: InProgress
# .........
# 2021-02-07 06:56:16 Starting - Preparing the instances for training......
# 2021-02-07 06:57:17 Downloading - Downloading input data...
# 2021-02-07 06:57:41 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/07/2021 06:57:58 INFO 140064705316672] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/07/2021 06:57:58 INFO 140064705316672] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'multiclass_classifier', u'balance_multiclass_weights': u'True', u'epochs': u'50', u'feature_dim': u'58', u'mini_batch_size': u'1000', u'num_classes': u'13'}
# [02/07/2021 06:57:58 INFO 140064705316672] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'50', u'feature_dim': u'58', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'13', u'predictor_type': u'multiclass_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'True', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/07/2021 06:57:58 WARNING 140064705316672] Loggers have already been setup.
# Process 1 is a worker.
# [02/07/2021 06:57:58 INFO 140064705316672] Using default worker.
# [02/07/2021 06:57:59 INFO 140064705316672] Checkpoint loading and saving are disabled.
# [2021-02-07 06:57:59.024] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2021-02-07 06:57:59.065] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 47, "num_examples": 1, "num_bytes": 280000}
# [02/07/2021 06:57:59 INFO 140064705316672] Create Store: local
# [2021-02-07 06:57:59.212] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 145, "num_examples": 11, "num_bytes": 3080000}
# [02/07/2021 06:57:59 INFO 140064705316672] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f63046a6e90>
# [02/07/2021 06:57:59 INFO 140064705316672] Scaling model computed with parameters:
#  {'stdev_weight':
# [2.45891599e-04 2.29178309e+00 6.14422262e-01 5.58951914e-01
#  5.94380759e-02 5.78992330e-02 1.45493060e-01 3.63543451e-01
#  3.62423867e-01 1.92072570e-01 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.18984558e-01 9.10696685e-02 1.00000000e+00
#  1.00000000e+00 2.48440981e-01 3.92818749e-02 4.76189293e-02
#  3.30108926e-02 1.19724192e-01 1.11699104e-01 1.00000000e+00
#  1.00000000e+00 1.00000000e+00
"Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612681170.075254}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 94822.07181296838, "sum": 94822.07181296838, "min": 94822.07181296838}}, "EndTime": 1612681170.075329, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612681170.075314}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 244467.89473954006, "sum": 244467.89473954006, "min": 244467.89473954006}}, "EndTime": 1612681170.075386, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612681170.07537}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 55221.90015121096, "sum": 55221.90015121096, "min": 55221.90015121096}}, "EndTime": 1612681170.075444, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612681170.075427}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 159076.8425567296, "sum": 159076.8425567296, "min": 159076.8425567296}}, "EndTime": 1612681170.075514, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612681170.075495}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 54246.864193081194, "sum": 54246.864193081194, "min": 54246.864193081194}}, "EndTime": 1612681170.075579, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612681170.07556}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 113118.39517255742, "sum": 113118.39517255742, "min": 113118.39517255742}}, "EndTime": 1612681170.075642, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612681170.075624}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 317575.80806050124, "sum": 317575.80806050124, "min": 317575.80806050124}}, "EndTime": 1612681170.075704, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612681170.075687}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 370498.08009706694, "sum": 370498.08009706694, "min": 370498.08009706694}}, "EndTime": 1612681170.075768, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612681170.07575}
#
# [02/07/2021 06:59:30 INFO 140064705316672] #quality_metric: host=algo-1, epoch=0, validation weighted_softmax_loss_objective <loss>=96703.9262305
# [02/07/2021 06:59:30 INFO 140064705316672] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=weighted_softmax_loss_objective, value=54246.8641931
# [02/07/2021 06:59:30 INFO 140064705316672] Epoch 0: Loss improved. Updating best model
# [02/07/2021 06:59:30 INFO 140064705316672] Saving model for epoch: 0
# [02/07/2021 06:59:30 INFO 140064705316672] Saved checkpoint to "/tmp/tmpinxVkZ/mx-mod-0000.params"
# [02/07/2021 06:59:30 INFO 140064705316672] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1595, "sum": 1595.0, "min": 1595}, "Number of Batches Since Last Reset": {"count": 1, "max": 1595, "sum": 1595.0, "min": 1595}, "Number of Records Since Last Reset": {"count": 1, "max": 1594470, "sum": 1594470.0, "min": 1594470}, "Total Batches Seen": {"count": 1, "max": 1607, "sum": 1607.0, "min": 1607}, "Total Records Seen": {"count": 1, "max": 1606470, "sum": 1606470.0, "min": 1606470}, "Max Records Seen Between Resets": {"count": 1, "max": 1594470, "sum": 1594470.0, "min": 1594470}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1612681170.087078, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612681079.400753}
#
# [02/07/2021 06:59:30 INFO 140064705316672] #throughput_metric: host=algo-1, train throughput=17582.2342427 records/second
# [2021-02-07 07:00:56.911] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 86822, "num_examples": 1595, "num_bytes": 446451600}
# #metrics {"Metrics": {"train_weighted_softmax_loss_objective": {"count": 1, "max": 41713.39299266169, "sum": 41713.39299266169, "min": 41713.39299266169}}, "EndTime": 1612681256.911436, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681256.911169}
#
# #metrics {"Metrics": {"train_weighted_softmax_loss_objective": {"count": 1, "max": 249343.5286207908, "sum": 249343.5286207908, "min": 249343.5286207908}}, "EndTime": 1612681256.911534, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681256.911518}
#
# #metrics {"Metrics": {"train_weighted_softmax_loss_objective": {"count": 1, "max": 38833.00793391386, "sum": 38833.00793391386, "min": 38833.00793391386}}, "EndTime": 1612681256.911581, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681256.91157}
#
# #metrics {"Metrics": {"train_weighted_softmax_loss_objective": {"count": 1, "max": 25553.207297412926, "sum": 25553.207297412926, "min": 25553.207297412926}}, "EndTime": 1612681256.911622, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681256.911612}
#
# #metrics {"Metrics": {"train_weighted_softmax_loss_objective": {"count": 1, "max": 254428.75286775926, "sum": 254428.75286775926, "min": 254428.75286775926}}, "EndTime": 1612681256.911661, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681256.911651}
#
# #metrics {"Metrics": {"train_weighted_softmax_loss_objective": {"count": 1, "max": 34097.43810836413, "sum": 34097.43810836413, "min": 34097.43810836413}}, "EndTime": 1612681256.911699, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681256.91169}
#
# #metrics {"Metrics": {"train_weighted_softmax_loss_objective": {"count": 1, "max":

#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 198720.8308944247, "sum": 198720.8308944247, "min": 198720.8308944247}}, "EndTime": 1612681260.489291, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681260.489274}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 98104.94876003082, "sum": 98104.94876003082, "min": 98104.94876003082}}, "EndTime": 1612681260.489361, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681260.489342}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 130878.05932831547, "sum": 130878.05932831547, "min": 130878.05932831547}}, "EndTime": 1612681260.489432, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681260.489414}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 90422.74963496582, "sum": 90422.74963496582, "min": 90422.74963496582}}, "EndTime": 1612681260.489504, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681260.489485}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 228299.0676689125, "sum": 228299.0676689125, "min": 228299.0676689125}}, "EndTime": 1612681260.489575, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681260.489556}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 50142.44589377958, "sum": 50142.44589377958, "min": 50142.44589377958}}, "EndTime": 1612681260.489644, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681260.489626}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 120055.1103872405, "sum": 120055.1103872405, "min": 120055.1103872405}}, "EndTime": 1612681260.48971, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681260.489692}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 53030.941606485125, "sum": 53030.941606485125, "min": 53030.941606485125}}, "EndTime": 1612681260.489761, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681260.48975}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 114923.33402070764, "sum": 114923.33402070764, "min": 114923.33402070764}}, "EndTime": 1612681260.489797, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681260.489784}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 283058.1370349991, "sum": 283058.1370349991, "min": 283058.1370349991}}, "EndTime": 1612681260.489843, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681260.489833}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 487965.0105156884, "sum": 487965.0105156884, "min": 487965.0105156884}}, "EndTime": 1612681260.489905, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681260.489887}
#
# [02/07/2021 07:01:00 INFO 140064705316672] #quality_metric: host=algo-1, epoch=1, validation weighted_softmax_loss_objective <loss>=73886.4297484
# [02/07/2021 07:01:00 INFO 140064705316672] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=weighted_softmax_loss_objective, value=50142.4458938
# [02/07/2021 07:01:00 INFO 140064705316672] Epoch 1: Loss improved. Updating best model
# [02/07/2021 07:01:00 INFO 140064705316672] Saving model for epoch: 1
# [02/07/2021 07:01:00 INFO 140064705316672] Saved checkpoint to "/tmp/tmpNOSU4l/mx-mod-0000.params"
# [02/07/2021 07:01:00 INFO 140064705316672] #progress_metric: host=algo-1, completed 4 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1595, "sum": 1595.0, "min": 1595}, "Number of Batches Since Last Reset": {"count": 1, "max": 1595, "sum": 1595.0, "min": 1595}, "Number of Records Since Last Reset": {"count": 1, "max": 1594470, "sum": 1594470.0, "min": 1594470}, "Total Batches Seen": {"count": 1, "max": 3202, "sum": 3202.0, "min": 3202}, "Total Records Seen": {"count": 1, "max": 3200940, "sum": 3200940.0, "min": 3200940}, "Max Records Seen Between Resets": {"count": 1, "max": 1594470, "sum": 1594470.0, "min": 1594470}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1612681260.499073, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612681170.088692}
#
# [02/07/2021 07:01:00 INFO 140064705316672] #throughput_metric: host=algo-1, train throughput=17635.8913074 records/second
# [2021-02-07 07:02:27.739] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 87239, "num_examples": 1595, "num_bytes": 446451600}
# #metrics {"Metrics": {"train_weighted_softmax_loss_objective": {"count": 1, "max": 38103.65518605629, "sum": 38103.65518605629, "min": 38103.65518605629}}, "EndTime": 1612681347.739829, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612681347.739749}
#
# #metrics {"Metrics": {"train_weighted_softmax_loss_objective": {"count": 1, "max": 243916.8640740446, "sum": 243916.8640740446, "min": 243916.8640740446}}, "EndTime": 1612681347.739914, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612681347.739899}
#
# #metrics {"Metrics": {"train_weighted_softmax_loss_objective": {"count": 1, "max": 114097.257211775, "sum": 114097.257211775, "min": 114097.257211775}}, "EndTime": 1612681347.739959, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612681347.739948}
#
# #metrics {"Metrics": {"train_weighted_softmax_loss_objective": {"count": 1, "max": 25437.554681073125, "sum": 25437.554681073125, "min": 25437.554681073125}}, "EndTime": 1612681347.74, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612681347
"Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682341.518835}
#
# [02/07/2021 07:19:01 INFO 140064705316672] #quality_metric: host=algo-1, epoch=13, train weighted_softmax_loss_objective <loss>=36275.4620422
# [2021-02-07 07:19:05.813] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 41, "duration": 4271, "num_examples": 138, "num_bytes": 38427480}
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 69178.90365164685, "sum": 69178.90365164685, "min": 69178.90365164685}}, "EndTime": 1612682345.824736, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.82466}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 127467.54258929945, "sum": 127467.54258929945, "min": 127467.54258929945}}, "EndTime": 1612682345.824831, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.824811}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 49813.841073666146, "sum": 49813.841073666146, "min": 49813.841073666146}}, "EndTime": 1612682345.824894, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.824876}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 86601.30150867133, "sum": 86601.30150867133, "min": 86601.30150867133}}, "EndTime": 1612682345.82496, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.824946}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 170956.33098742302, "sum": 170956.33098742302, "min": 170956.33098742302}}, "EndTime": 1612682345.825028, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.82501}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 56741.71406004367, "sum": 56741.71406004367, "min": 56741.71406004367}}, "EndTime": 1612682345.82507, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.825061}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 59523.4585974103, "sum": 59523.4585974103, "min": 59523.4585974103}}, "EndTime": 1612682345.825101, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.825093}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 75506.95135578676, "sum": 75506.95135578676, "min": 75506.95135578676}}, "EndTime": 1612682345.825128, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.825121}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 53683.44770484722, "sum": 53683.44770484722, "min": 53683.44770484722}}, "EndTime": 1612682345.825154, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.825148}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 102430.9282084071, "sum": 102430.9282084071, "min": 102430.9282084071}}, "EndTime": 1612682345.82518, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.825174}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 195554.94101659558, "sum": 195554.94101659558, "min": 195554.94101659558}}, "EndTime": 1612682345.825207, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.8252}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 100908.10506271529, "sum": 100908.10506271529, "min": 100908.10506271529}}, "EndTime": 1612682345.825251, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.825241}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 118978.6926817634, "sum": 118978.6926817634, "min": 118978.6926817634}}, "EndTime": 1612682345.82528, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.825273}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 93190.57097718953, "sum": 93190.57097718953, "min": 93190.57097718953}}, "EndTime": 1612682345.825306, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.825299}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 109739.48909906889, "sum": 109739.48909906889, "min": 109739.48909906889}}, "EndTime": 1612682345.825357, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.825342}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 54643.06749190293, "sum": 54643.06749190293, "min": 54643.06749190293}}, "EndTime": 1612682345.825414, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.825397}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 74825.65085056095, "sum": 74825.65085056095, "min": 74825.65085056095}}, "EndTime": 1612682345.825472, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.825456}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 52273.90948026077, "sum": 52273.90948026077, "min": 52273.90948026077}}, "EndTime": 1612682345.82553, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.825513}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 53615.57605237434, "sum": 53615.57605237434, "min": 53615.57605237434}}, "EndTime": 1612682345.825591, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.825574}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 287267.49578297994, "sum": 287267.49578297994, "min": 287267.49578297994}}, "EndTime": 1612682345.825651, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.825636}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 299949.904807254, "sum": 299949.904807254, "min": 299949.904807254}}, "EndTime": 1612682345.825696, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682345.825686}
#
# [02/07/2021 07:19:05 INFO 140064705316672] #quality_metric: host=algo-1, epoch=13, validation weighted_softmax_loss_objective <loss>=69178.9036516
# [02/07/2021 07:19:05 INFO 140064705316672] #early_stopping_criteria_metric: host=algo-1, epoch=13, criteria=weighted_softmax_loss_objective, value=49813.8410737
# [02/07/2021 07:19:05 INFO 140064705316672] Saving model for epoch: 13
# [02/07/2021 07:19:05 INFO 140064705316672] Saved checkpoint to "/tmp/tmpYzcOW8/mx-mod-0000.params"
# [02/07/2021 07:19:05 INFO 140064705316672] Early stop condition met. Stopping training.
# [02/07/2021 07:19:05 INFO 140064705316672] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1595, "sum": 1595.0, "min": 1595}, "Number of Batches Since Last Reset": {"count": 1, "max": 1595, "sum": 1595.0, "min": 1595}, "Number of Records Since Last Reset": {"count": 1, "max": 1594470, "sum": 1594470.0, "min": 1594470}, "Total Batches Seen": {"count": 1, "max": 22342, "sum": 22342.0, "min": 22342}, "Total Records Seen": {"count": 1, "max": 22334580, "sum": 22334580.0, "min": 22334580}, "Max Records Seen Between Resets": {"count": 1, "max": 1594470, "sum": 1594470.0, "min": 1594470}, "Reset Count": {"count": 1, "max": 16, "sum": 16.0, "min": 16}}, "EndTime": 1612682345.835931, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612682254.933263}
#
# [02/07/2021 07:19:05 INFO 140064705316672] #throughput_metric: host=algo-1, train throughput=17540.3832265 records/second
# [02/07/2021 07:19:05 WARNING 140064705316672] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/07/2021 07:19:05 WARNING 140064705316672] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-02-07 07:19:09.419] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 44, "duration": 3561, "num_examples": 138, "num_bytes": 38427480}
# [02/07/2021 07:19:09 INFO 140064705316672] #early_stopping_criteria_metric: host=algo-1, epoch=13, criteria=weighted_softmax_loss_objective, value=49813.8410737
# [2021-02-07 07:19:10.485] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 46, "duration": 1052, "num_examples": 138, "num_bytes": 38427480}
# [02/07/2021 07:19:10 INFO 140064705316672] #validation_score (algo-1) : ('weighted_softmax_loss_objective', 49692.42070979381)
# [02/07/2021 07:19:10 INFO 140064705316672] #validation_score (algo-1) : ('multiclass_accuracy', 0.0693451665318673)
# [02/07/2021 07:19:10 INFO 140064705316672] #validation_score (algo-1) : ('multiclass_top_k_accuracy_3', 0.14167777850642302)
# [02/07/2021 07:19:10 INFO 140064705316672] #validation_score (algo-1) : ('dcg', 0.39652643553890543)
# [02/07/2021 07:19:10 INFO 140064705316672] #validation_score (algo-1) : ('macro_recall', 0.11617407)
# [02/07/2021 07:19:10 INFO 140064705316672] #validation_score (algo-1) : ('macro_precision', nan)
# [02/07/2021 07:19:10 INFO 140064705316672] #validation_score (algo-1) : ('macro_f_1.000', 0.034171436)
# [02/07/2021 07:19:10 INFO 140064705316672] #quality_metric: host=algo-1, validation weighted_softmax_loss_objective <loss>=49692.4207098
# [02/07/2021 07:19:10 INFO 140064705316672] #quality_metric: host=algo-1, validation multiclass_accuracy <score>=0.0693451665319
# [02/07/2021 07:19:10 INFO 140064705316672] #quality_metric: host=algo-1, validation multiclass_top_k_accuracy_3 <score>=0.141677778506
# [02/07/2021 07:19:10 INFO 140064705316672] #quality_metric: host=algo-1, validation dcg <score>=0.396526435539
# [02/07/2021 07:19:10 INFO 140064705316672] #quality_metric: host=algo-1, validation macro_recall <score>=0.116174072027
# [02/07/2021 07:19:10 INFO 140064705316672] #quality_metric: host=algo-1, validation macro_precision <score>=nan
# [02/07/2021 07:19:10 INFO 140064705316672] #quality_metric: host=algo-1, validation macro_f_1.000 <score>=0.034171435982
# [02/07/2021 07:19:10 INFO 140064705316672] Best model found for hyperparameters: {"lr_scheduler_step": 17, "wd": 0.013714606834336346, "optimizer": "rmsprop", "lr_scheduler_factor": 0.9848233889007437, "l1": 0.12007663993206846, "learning_rate": 0.04894414201957118, "lr_scheduler_minimum_lr": 0.00016053955926854287}
# [02/07/2021 07:19:10 INFO 140064705316672] Saved checkpoint to "/tmp/tmpcRQ7D9/mx-mod-0000.params"
# [02/07/2021 07:19:10 INFO 140064705316672] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1271737.8339767456, "sum": 1271737.8339767456, "min": 1271737.8339767456}, "finalize.time": {"count": 1, "max": 4707.227945327759, "sum": 4707.227945327759, "min": 4707.227945327759}, "initialize.time": {"count": 1, "max": 367.1400547027588, "sum": 367.1400547027588, "min": 367.1400547027588}, "check_early_stopping.time": {"count": 15, "max": 1.0249614715576172, "sum": 8.182287216186523, "min": 0.14591217041015625}, "setuptime": {"count": 1, "max": 24.137020111083984, "sum": 24.137020111083984, "min": 24.137020111083984}, "update.time": {"count": 14, "max": 91184.33499336243, "sum": 1266373.8405704498, "min": 89725.92115402222}, "epochs": {"count": 1, "max": 50, "sum": 50.0, "min": 50}}, "EndTime": 1612682350.553309, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1612681079.017218}
#
#
# 2021-02-07 07:19:38 Uploading - Uploading generated training model
# 2021-02-07 07:19:38 Completed - Training job completed
# ProfilerReport-1612680855: NoIssuesFound
# Training seconds: 1335
# Billable seconds: 1335

# %%
# %%time 
# deploy and create a predictor
multiclass_predictor = multiclass_estimator.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -----------------!CPU times: user 322 ms, sys: 17.8 ms, total: 340 ms
# Wall time: 8min 32s

# %%
test_x_np = test_x.values
result = multiclass_predictor.predict(test_x_np[0])

# %%
result
# Out:
# [label {
#    key: "predicted_label"
#    value {
#      float32_tensor {
#        values: 12.0
#      }
#    }
#  }
#  label {
#    key: "score"
#    value {
#      float32_tensor {
#        values: 2.6244238142680842e-06
#        values: 1.000000013351432e-10
#        values: 4.3790746029337413e-10
#        values: 6.731854682584526e-07
#        values: 1.000000013351432e-10
#        values: 6.794044771218921e-10
#        values: 1.000000013351432e-10
#        values: 4.790722263336988e-10
#        values: 5.5270419352382305e-09
#        values: 0.0246282871812582
#        values: 0.09284412115812302
#        values: 0.004488704260438681
#        values: 0.8780355453491211
#      }
#    }
#  }]

# %%
prediction_batches = [multiclass_predictor.predict(batch) for batch in np.array_split(test_x_np, 100)]
test_y_preds = np.concatenate([np.array([x.label['predicted_label'].float32_tensor.values[0] for x in batch]) 
                                 for batch in prediction_batches])

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
test_y_np = test_y.values.astype('float32')
accuracy_multiclass = accuracy_score(test_y_np, test_y_preds)
f1_score_multiclass = f1_score(test_y_np, test_y_preds, average=None)

# %%
accuracy_multiclass
# Out:
# 0.08657749337542989

# %%
from utils import print_f1_scores
df_f1_score_multiclass = print_f1_scores(f1_score_multiclass)

# %%
df_f1_score_multiclass
# Out:
#    Causes Description  F1 scores
# 0           Lightning   0.000000
# 1       Equipment Use   0.000000
# 2             Smoking   0.000000
# 3            Campfire   0.000000
# 4      Debris Burning   0.071673
# 5            Railroad   0.035833
# 6               Arson   0.000000
# 7            Children   0.000000
# 8       Miscellaneous   0.004566
# 9           Fireworks   0.123243
# 10          Powerline   0.078906
# 11          Structure   0.000000
# 12  Missing/Undefined   0.149834

# %%
multiclass_estimator.delete_endpoint()
# Out:
# The function delete_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
